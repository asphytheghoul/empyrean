# %%
import tensorflow as tf
import librosa 
import librosa.display
from keras.api._v2.keras.models import Sequential
from keras.api._v2.keras.layers import Conv2D,BatchNormalization,Dropout,Flatten,Dense

# %%
wav,sr = librosa.load("Parsed_Capuchinbird_Clips/XC114131-0.wav")
librosa.display.waveshow(wav,sr=sr)

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
CAPUCHIN = "Gunshots/106955-6-0-0.wav"
NOT_CAPUCHIN = 'Parsed_Not_Capuchinbird_Clips/afternoon-birds-song-in-forest-4.wav'

# %%
def get_audio(file_path):
    wav,sr = librosa.load(file_path)
    librosa.display.waveshow(wav,sr=sr)

# %%
get_audio("Parsed_Capuchinbird_Clips/XC114131-1.wav")
